# %%
##########################################
# Nikolaos Paraskakis / I.D.: 2018030027 #
# Advanced Topics in Convex Optimization #
##########################################

# %%
########################################################
#            Modern Portfolio Theory                   #
#             Portfolio Optimization                   #
#         Using SCIPY OPTIMIZE MINIMIZE                #
########################################################

# %%
pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting yfinance
#   Downloading yfinance-0.1.85-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.9.1)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.11)
# Collecting requests>=2.26
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 592 kB/s
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2022.9.24)
# Installing collected packages: requests, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# Successfully installed requests-2.28.1 yfinance-0.1.85

# %%
pip install PyPortfolioOpt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting PyPortfolioOpt
#   Downloading pyportfolioopt-1.5.2-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 2.6 MB/s
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.10 in /usr/local/lib/python3.7/dist-packages (from PyPortfolioOpt) (1.2.1)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from PyPortfolioOpt) (1.3.5)
# Requirement already satisfied: numpy<2.0,>=1.12 in /usr/local/lib/python3.7/dist-packages (from PyPortfolioOpt) (1.21.6)
# Requirement already satisfied: scipy<2.0,>=1.3 in /usr/local/lib/python3.7/dist-packages (from PyPortfolioOpt) (1.7.3)
# Requirement already satisfied: ecos>=2 in /usr/local/lib/python3.7/dist-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (2.0.10)
# Requirement already satisfied: scs>=1.1.6 in /usr/local/lib/python3.7/dist-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (3.2.0)
# Requirement already satisfied: osqp>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (0.6.2.post0)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.7/dist-packages (from osqp>=0.4.1->cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt) (0.1.5.post2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->PyPortfolioOpt) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->PyPortfolioOpt) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->PyPortfolioOpt) (1.15.0)
# Installing collected packages: PyPortfolioOpt
# Successfully installed PyPortfolioOpt-1.5.2

# %%
# Import libraries

from pandas_datareader import data as web
from pandas_datareader import DataReader
import pandas as pd
import numpy as np
from datetime import datetime
import datetime 
import yfinance as yf
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
from pypfopt.discrete_allocation import DiscreteAllocation, get_latest_prices
from pypfopt import EfficientFrontier
from pypfopt import risk_models
from pypfopt import expected_returns
from pypfopt import plotting
from pypfopt.discrete_allocation import DiscreteAllocation, get_latest_prices
import plotly.offline as py
import plotly.figure_factory as ff
import plotly.graph_objects as go
import copy
import scipy.optimize as sc

# %%
# Function to plot any graph

def plot_graph(col,title,xlabel,ylabel,df):

    data = []
    
    for i in range(len(col)): 
        plot = go.Scatter(x=df.index,y=df[col[i]], name=col[i])
        data.append(plot)
    
    layout = go.Layout(title= title,
                       xaxis=dict(title=xlabel),
                       yaxis=dict(title=ylabel ),
                       width = 690,
                       height = 500,
                       autosize = False)

    fig = go.Figure(data=data, layout=layout)
    
    fig.show()

# %%
# Function to plot any table 

def plot_table(table, index_title = "", title = "" , layout_width = 900):
    
    colorscale = [[0, '#1a88ff'],[.5, '#e6f2ff'],[1, '#ffffff']]
    
    table = ff.create_table(round(table,4),
                            index = True,
                            index_title=index_title,
                            colorscale=colorscale )
    
    table.update_layout(title_text = title)
    
    table.layout.width=layout_width
    
    py.iplot(table)

# %%
# FUNCTION to calculate portfolio performance

def portfolioPerformance(weights, annual_meanReturns, annual_covMatrix):

  annual_returns = np.dot(weights.T, annual_meanReturns)

  annual_variance = np.dot(weights.T, np.dot(annual_covMatrix, weights))

  annual_sd = np.sqrt(annual_variance)

  return annual_returns, annual_variance, annual_sd

# %%
# FUNCTION to calculate portfolio volatility

def portfolioVolatility(weights, covMatrix):

  volatility = np.sqrt(np.dot(weights.T, np.dot(covMatrix, weights)))

  return volatility

# %%
# FUNCTION to calculate portfolio return

def portfolioReturn(weights, mean_returns):

  portReturn = np.dot(weights.T, mean_returns)

  return portReturn

# %%
# FUNCTION to calculate negative portfolio return

def negativePortfolioReturn(weights, mean_returns):

  NegPortReturn = - portfolioReturn(weights, mean_returns)

  return NegPortReturn

# %%
# FUNCTION to calculate Sharpe Ratio

def SR(weights, annual_meanReturns, annual_covMatrix, riskFreeRateOfReturn):
  
  annual_returns, annual_variance, annual_sd = portfolioPerformance(weights,
                                                                  annual_meanReturns,
                                                                  annual_covMatrix)
  
  portfolioRateOfReturn = annual_returns

  portfolio_sd = annual_sd

  SR = (portfolioRateOfReturn - riskFreeRateOfReturn)/portfolio_sd
  
  return SR

# %%
# FUNCTION to calculate negative Sharpe Ratio

def negativeSR(weights, annual_meanReturns, annual_covMatrix, riskFreeRateOfReturn):
  negativeSR = -SR(weights, annual_meanReturns, annual_covMatrix, riskFreeRateOfReturn)
  return negativeSR

# %%
# FUNCTION to calculate Sharpe Ratio

def utility(weights, risk_aversion, annual_meanReturns, annual_covMatrix):
  
  annual_returns, annual_variance, annual_sd = portfolioPerformance(weights,
                                                                  annual_meanReturns,
                                                                  annual_covMatrix)
  
  portfolioRateOfReturn = annual_returns

  portfolio_var = annual_variance
  
  portfolio_sd = annual_sd

  utility = portfolioRateOfReturn - risk_aversion * (1/2) * portfolio_var
  
  return utility

# %%
def negativeUtility(weights, risk_aversion, annual_meanReturns, annual_covMatrix):
  negativeUtility = -utility(weights, risk_aversion, annual_meanReturns, annual_covMatrix)
  return negativeUtility

# %%
# FUNCTION to optimize portfolio by minimizing volatility

def minVol(annual_covMatrix, constraintSet):
  numOfAssets = len(annual_covMatrix)
  args = (annual_covMatrix)
  constraints = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1})
  bound = constraintSet
  bounds = tuple(bound for asset in range (numOfAssets))
  result = sc.minimize(portfolioVolatility, numOfAssets*[1./numOfAssets],
                       args = args, method ='SLSQP', bounds = bounds,
                       constraints = constraints)
  return result

# %%
# FUNCTION to optimize portfolio by maximizing Sharpe ratio

def maxSR(annual_meanReturns, annual_covMatrix, riskFreeRateOfReturn, constraintSet):
  numOfAssets = len(annual_meanReturns)
  args = (annual_meanReturns, annual_covMatrix, riskFreeRateOfReturn)
  constraints = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1})
  bound = constraintSet
  bounds = tuple(bound for asset in range (numOfAssets))
  result = sc.minimize(negativeSR, numOfAssets*[1./numOfAssets],
                       args = args, method ='SLSQP', bounds = bounds,
                       constraints = constraints)
  return result

# %%
# FUNCTION to optimize portfolio by maximizing return on target risk

def efRetOnTargetRisk(targetRisk, annual_meanReturns, annual_covMatrix, constraintSet):
  numOfAssets = len(annual_meanReturns)
  args = (annual_meanReturns)
  constraints = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1},{'type': 'eq', 'fun': lambda x: portfolioVolatility(x,annual_covMatrix) - targetRisk})
  bound = constraintSet
  bounds = tuple(bound for asset in range (numOfAssets))
  result = sc.minimize(negativePortfolioReturn, numOfAssets*[1./numOfAssets],
                       args = args, method ='SLSQP', bounds = bounds,
                       constraints = constraints)
  return result

# %%
# FUNCTION to optimize portfolio by minimizing risk on target return

def efRiskOnTargetReturn(targetReturn, annual_meanReturns, annual_covMatrix, constraintSet):
  numOfAssets = len(annual_meanReturns)
  args = (annual_covMatrix)
  constraints = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1},{'type': 'eq', 'fun': lambda x: portfolioReturn(x,annual_meanReturns) - targetReturn})
  bound = constraintSet
  bounds = tuple(bound for asset in range (numOfAssets))
  result = sc.minimize(portfolioVolatility, numOfAssets*[1./numOfAssets],
                       args = args, method ='SLSQP', bounds = bounds,
                       constraints = constraints)
  return result

# %%
# FUNCTION to optimize portfolio by minimizing risk on target return

def maxUtility(risk_aversion, annual_meanReturns, annual_covMatrix, constraintSet):
  numOfAssets = len(annual_meanReturns)
  args = (risk_aversion, annual_meanReturns, annual_covMatrix)
  constraints = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1})
  bound = constraintSet
  bounds = tuple(bound for asset in range (numOfAssets))
  result = sc.minimize(negativeUtility, numOfAssets*[1./numOfAssets],
                       args = args, method ='SLSQP', bounds = bounds,
                       constraints = constraints)
  return result

# %%
# Get the symbols of the assets in the portfolio

assets = ['META', 'AMZN', 'NFLX', 'GOOG', 'BA', 'V', 'MA']

# %%
# Assign equal weights to the assets (initial guess).

numOfAssets = len(assets)
weights = numOfAssets*[1./numOfAssets]

# %%
# Get the stock/portfolio starting date
startDate = (datetime.datetime.today() - datetime.timedelta(days = 365*5)).strftime("%Y-%m-%d")

# Get the stock/portfolio ending date
endDate = datetime.datetime.today().strftime('%Y-%m-%d')

# %%
# Create a dataframe to store the adjusted closing price of the stocks
df = pd.DataFrame()

# Store the adjusted closing price of the stock into the df
for asset in assets:
  df[asset] = yf.download(asset,
                          start = startDate,
                          end = endDate,
                          progress = False)['Adj Close']

my_assets = df

my_assets
# Out:
#                   META        AMZN        NFLX       GOOG          BA  \
# Date
# 2017-11-06  180.169998   56.033001  200.130005  51.294998  250.311203
# 2017-11-07  180.250000   56.158501  195.889999  51.666500  252.263916
# 2017-11-08  179.559998   56.644001  196.440002  51.992500  251.733032
# 2017-11-09  179.300003   56.456501  193.899994  51.563000  250.351257
# 2017-11-10  178.460007   56.267502  192.020004  51.403500  248.588196
# ...                ...         ...         ...        ...         ...
# 2022-10-28   99.199997  103.410004  295.720001  96.580002  143.839996
# 2022-10-31   93.160004  102.440002  291.880005  94.660004  142.509995
# 2022-11-01   95.199997   96.790001  286.750000  90.500000  143.380005
# 2022-11-02   90.540001   92.120003  273.000000  87.070000  147.410004
# 2022-11-03   88.910004   89.300003  269.059998  83.489998  156.750000
#
#                      V          MA
# Date
# 2017-11-06  108.355034  146.081161
# 2017-11-07  108.519608  145.964355
# 2017-11-08  108.887527  145.964355
# 2017-11-09  108.568031  145.302521
# 2017-11-10  108.316322  145.545807
# ...                ...         ...
# 2022-10-28  209.339996  329.470001
# 2022-10-31  207.160004  328.179993
# 2022-11-01  206.929993  333.190002
# 2022-11-02  200.949997  319.820007
# 2022-11-03  194.750000  309.170013
#
# [1258 rows x 7 columns]

# %%
# Portfolio Adjusted Closing Price History

title = 'Portfolio Adjusted Closing Price History'
xlabel = 'Date'
ylabel = 'Adjusted Closing Price USD ($)'

col = list(my_assets.columns.values)
plot_graph(col,title,xlabel,ylabel,my_assets)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ecefae3b-a58e-403b-bea3-7e79a3c61ce7" class="plotly-graph-div" style="height:500px; width:690px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ecefae3b-a58e-403b-bea3-7e79a3c61ce7")) {                    Plotly.newPlot(                        "ecefae3b-a58e-403b-bea3-7e79a3c61ce7",                        [{"name":"META","x":["2017-11-06T00:00:00","2017-11-07T00:00:00","2017-11-08T00:00:00","2017-11-09T00:00:00","2017-11-10T00:00:00","2017-11-13T00:00:00","2017-11-14T00:00:00","2017-11-15T00:00:00","2017-11-16T00:00:00","2017-11-17T00:00:00","2017-11-20T00:00:00","2017-11-21T00:00:00","2017-11-22T00:00:00","2017-11-24T00:00:00","2017-11-27T00:00:00","2017-11-28T00:00:00","2017-11-29T00:00:00","2017-11-30T00:00:00","2017-12-01T00:00:00","2017-12-04T00:00:00","2017-12-05T00:00:00","2017-12-06T00:00:00","2017-12-07T00:00:00","2017-12-08T00:00:00","2017-12-11T00:00:00","2017-12-12T00:00:00","2017-12-13T00:00:00","2017-12-14T00:00:00","2017-12-15T00:00:00","2017-12-18T00:00:00","2017-12-19T00:00:00","2017-12-20T00:00:00","2017-12-21T00:00:00","2017-12-22T00:00:00","2017-12-26T00:00:00","2017-12-27T00:00:00","2017-12-28T00:00:00","2017-12-29T00:00:00","2018-01-02T00:00:00","2018-01-03T00:00:00","2018-01-04T00:00:00","2018-01-05T00:00:00","2018-01-08T00:00:00","2018-01-09T00:00:00","2018-01-10T00:00:00","2018-01-11T00:00:00","2018-01-12T00:00:00","2018-01-16T00:00:00","2018-01-17T00:00:00","2018-01-18T00:00:00","2018-01-19T00:00:00","2018-01-22T00:00:00","2018-01-23T00:00:00","2018-01-24T00:00:00","2018-01-25T00:00:00","2018-01-26T00:00:00","2018-01-29T00:00:00","2018-01-30T00:00:00","2018-01-31T00:00:00","2018-02-01T00:00:00","2018-02-02T00:00:00","2018-02-05T00:00:00","2018-02-06T00:00:00","2018-02-07T00:00:00","2018-02-08T00:00:00","2018-02-09T00:00:00","2018-02-12T00:00:00","2018-02-13T00:00:00","2018-02-14T00:00:00","2018-02-15T00:00:00","2018-02-16T00:00:00","2018-02-20T00:00:00","2018-02-21T00:00:00","2018-02-22T00:00:00","2018-02-23T00:00:00","2018-02-26T00:00:00","2018-02-27T00:00:00","2018-02-28T00:00:00","2018-03-01T00:00:00","2018-03-02T00:00:00","2018-03-05T00:00:00","2018-03-06T00:00:00","2018-03-07T00:00:00","2018-03-08T00:00:00","2018-03-09T00:00:00","2018-03-12T00:00:00","2018-03-13T00:00:00","2018-03-14T00:00:00","2018-03-15T00:00:00","2018-03-16T00:00:00","2018-03-19T00:00:00","2018-03-20T00:00:00","2018-03-21T00:00:00","2018-03-22T00:00:00","2018-03-23T00:00:00","2018-03-26T00:00:00","2018-03-27T00:00:00","2018-03-28T00:00:00","2018-03-29T00:00:00","2018-04-02T00:00:00","2018-04-03T00:00:00","2018-04-04T00:00:00","2018-04-05T00:00:00","2018-04-06T00:00:00","2018-04-09T00:00:00","2018-04-10T00:00:00","2018-04-11T00:00:00","2018-04-12T00:00:00","2018-04-13T00:00:00","2018-04-16T00:00:00","2018-04-17T00:00:00","2018-04-18T00:00:00","2018-04-19T00:00:00","2018-04-20T00:00:00","2018-04-23T00:00:00","2018-04-24T00:00:00","2018-04-25T00:00:00","2018-04-26T00:00:00","2018-04-27T00:00:00","2018-04-30T00:00:00","2018-05-01T00:00:00","2018-05-02T00:00:00","2018-05-03T00:00:00","2018-05-04T00:00:00","2018-05-07T00:00:00","2018-05-08T00:00:00","2018-05-09T00:00:00","2018-05-10T00:00:00","2018-05-11T00:00:00","2018-05-14T00:00:00","2018-05-15T00:00:00","2018-05-16T00:00:00","2018-05-17T00:00:00","2018-05-18T00:00:00","2018-05-21T00:00:00","2018-05-22T00:00:00","2018-05-23T00:00:00","2018-05-24T00:00:00","2018-05-25T00:00:00","2018-05-29T00:00:00","2018-05-30T00:00:00","2018-05-31T00:00:00","2018-06-01T00:00:00","2018-06-04T00:00:00","2018-06-05T00:00:00","2018-06-06T00:00:00","2018-06-07T00:00:00","2018-06-08T00:00:00","2018-06-11T00:00:00","2018-06-12T00:00:00","2018-06-13T00:00:00","2018-06-14T00:00:00","2018-06-15T00:00:00","2018-06-18T00:00:00","2018-06-19T00:00:00","2018-06-20T00:00:00", ...

# %%
# Plot the annual covariance matrix

#plot_table(annual_covMatrix)

# %%
daily_returns = (my_assets-my_assets.shift(1))/my_assets.shift(1)
daily_returns = daily_returns.dropna()
daily_returns
# Out:
#                 META      AMZN      NFLX      GOOG        BA         V  \
# Date
# 2017-11-07  0.000444  0.002240 -0.021186  0.007242  0.007801  0.001519
# 2017-11-08 -0.003828  0.008645  0.002808  0.006310 -0.002104  0.003390
# 2017-11-09 -0.001448 -0.003310 -0.012930 -0.008261 -0.005489 -0.002934
# 2017-11-10 -0.004685 -0.003348 -0.009696 -0.003093 -0.007042 -0.002318
# 2017-11-13  0.001737  0.003394  0.015936 -0.002257  0.006019 -0.004290
# ...              ...       ...       ...       ...       ...       ...
# 2022-10-28  0.012865 -0.068042 -0.004109  0.042981  0.029193  0.024720
# 2022-10-31 -0.060887 -0.009380 -0.012985 -0.019880 -0.009246 -0.010414
# 2022-11-01  0.021898 -0.055154 -0.017576 -0.043947  0.006105 -0.001110
# 2022-11-02 -0.048950 -0.048249 -0.047951 -0.037901  0.028107 -0.028899
# 2022-11-03 -0.018003 -0.030612 -0.014432 -0.041116  0.063361 -0.030853
#
#                   MA
# Date
# 2017-11-07 -0.000800
# 2017-11-08  0.000000
# 2017-11-09 -0.004534
# 2017-11-10  0.001674
# 2017-11-13  0.001004
# ...              ...
# 2022-10-28  0.031625
# 2022-10-31 -0.003915
# 2022-11-01  0.015266
# 2022-11-02 -0.040127
# 2022-11-03 -0.033300
#
# [1257 rows x 7 columns]

# %%
# Visually show the daily returns per asset

title = 'Percentage daily returns per asset'
xlabel = 'Date'
ylabel = 'Percentage daily returns'

col = list(daily_returns.columns.values)
plot_graph(col,title,xlabel,ylabel,daily_returns)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7bc8df9a-b936-4ac9-98f2-77098599f931" class="plotly-graph-div" style="height:500px; width:690px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7bc8df9a-b936-4ac9-98f2-77098599f931")) {                    Plotly.newPlot(                        "7bc8df9a-b936-4ac9-98f2-77098599f931",                        [{"name":"META","x":["2017-11-07T00:00:00","2017-11-08T00:00:00","2017-11-09T00:00:00","2017-11-10T00:00:00","2017-11-13T00:00:00","2017-11-14T00:00:00","2017-11-15T00:00:00","2017-11-16T00:00:00","2017-11-17T00:00:00","2017-11-20T00:00:00","2017-11-21T00:00:00","2017-11-22T00:00:00","2017-11-24T00:00:00","2017-11-27T00:00:00","2017-11-28T00:00:00","2017-11-29T00:00:00","2017-11-30T00:00:00","2017-12-01T00:00:00","2017-12-04T00:00:00","2017-12-05T00:00:00","2017-12-06T00:00:00","2017-12-07T00:00:00","2017-12-08T00:00:00","2017-12-11T00:00:00","2017-12-12T00:00:00","2017-12-13T00:00:00","2017-12-14T00:00:00","2017-12-15T00:00:00","2017-12-18T00:00:00","2017-12-19T00:00:00","2017-12-20T00:00:00","2017-12-21T00:00:00","2017-12-22T00:00:00","2017-12-26T00:00:00","2017-12-27T00:00:00","2017-12-28T00:00:00","2017-12-29T00:00:00","2018-01-02T00:00:00","2018-01-03T00:00:00","2018-01-04T00:00:00","2018-01-05T00:00:00","2018-01-08T00:00:00","2018-01-09T00:00:00","2018-01-10T00:00:00","2018-01-11T00:00:00","2018-01-12T00:00:00","2018-01-16T00:00:00","2018-01-17T00:00:00","2018-01-18T00:00:00","2018-01-19T00:00:00","2018-01-22T00:00:00","2018-01-23T00:00:00","2018-01-24T00:00:00","2018-01-25T00:00:00","2018-01-26T00:00:00","2018-01-29T00:00:00","2018-01-30T00:00:00","2018-01-31T00:00:00","2018-02-01T00:00:00","2018-02-02T00:00:00","2018-02-05T00:00:00","2018-02-06T00:00:00","2018-02-07T00:00:00","2018-02-08T00:00:00","2018-02-09T00:00:00","2018-02-12T00:00:00","2018-02-13T00:00:00","2018-02-14T00:00:00","2018-02-15T00:00:00","2018-02-16T00:00:00","2018-02-20T00:00:00","2018-02-21T00:00:00","2018-02-22T00:00:00","2018-02-23T00:00:00","2018-02-26T00:00:00","2018-02-27T00:00:00","2018-02-28T00:00:00","2018-03-01T00:00:00","2018-03-02T00:00:00","2018-03-05T00:00:00","2018-03-06T00:00:00","2018-03-07T00:00:00","2018-03-08T00:00:00","2018-03-09T00:00:00","2018-03-12T00:00:00","2018-03-13T00:00:00","2018-03-14T00:00:00","2018-03-15T00:00:00","2018-03-16T00:00:00","2018-03-19T00:00:00","2018-03-20T00:00:00","2018-03-21T00:00:00","2018-03-22T00:00:00","2018-03-23T00:00:00","2018-03-26T00:00:00","2018-03-27T00:00:00","2018-03-28T00:00:00","2018-03-29T00:00:00","2018-04-02T00:00:00","2018-04-03T00:00:00","2018-04-04T00:00:00","2018-04-05T00:00:00","2018-04-06T00:00:00","2018-04-09T00:00:00","2018-04-10T00:00:00","2018-04-11T00:00:00","2018-04-12T00:00:00","2018-04-13T00:00:00","2018-04-16T00:00:00","2018-04-17T00:00:00","2018-04-18T00:00:00","2018-04-19T00:00:00","2018-04-20T00:00:00","2018-04-23T00:00:00","2018-04-24T00:00:00","2018-04-25T00:00:00","2018-04-26T00:00:00","2018-04-27T00:00:00","2018-04-30T00:00:00","2018-05-01T00:00:00","2018-05-02T00:00:00","2018-05-03T00:00:00","2018-05-04T00:00:00","2018-05-07T00:00:00","2018-05-08T00:00:00","2018-05-09T00:00:00","2018-05-10T00:00:00","2018-05-11T00:00:00","2018-05-14T00:00:00","2018-05-15T00:00:00","2018-05-16T00:00:00","2018-05-17T00:00:00","2018-05-18T00:00:00","2018-05-21T00:00:00","2018-05-22T00:00:00","2018-05-23T00:00:00","2018-05-24T00:00:00","2018-05-25T00:00:00","2018-05-29T00:00:00","2018-05-30T00:00:00","2018-05-31T00:00:00","2018-06-01T00:00:00","2018-06-04T00:00:00","2018-06-05T00:00:00","2018-06-06T00:00:00","2018-06-07T00:00:00","2018-06-08T00:00:00","2018-06-11T00:00:00","2018-06-12T00:00:00","2018-06-13T00:00:00","2018-06-14T00:00:00","2018-06-15T00:00:00","2018-06-18T00:00:00","2018-06-19T00:00:00","2018-06-20T00:00:00","2018-06-21T00:00:00", ...

# %%
# Mean daily volatility for each asset

daily_volatility = daily_returns.std()
daily_volatility = pd.DataFrame({'Asset':daily_volatility.index, 'Daily Volatility':daily_volatility.values})
plot_table(daily_volatility)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f1527a4d-45e5-4ee7-8218-855e7a7b5e4a" class="plotly-graph-div" style="height:290px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f1527a4d-45e5-4ee7-8218-855e7a7b5e4a")) {                    Plotly.newPlot(                        "f1527a4d-45e5-4ee7-8218-855e7a7b5e4a",                        [{"colorscale":[[0,"#1a88ff"],[0.5,"#e6f2ff"],[1,"#ffffff"]],"hoverinfo":"none","opacity":0.75,"showscale":false,"z":[[0,0,0],[0,0.5,0.5],[0,1,1],[0,0.5,0.5],[0,1,1],[0,0.5,0.5],[0,1,1],[0,0.5,0.5]],"type":"heatmap"}],                        {"annotations":[{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b></b>","x":-0.45,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Asset</b>","x":0.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Daily Volatility</b>","x":1.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>0</b>","x":-0.45,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"META","x":0.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0267","x":1.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>1</b>","x":-0.45,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"AMZN","x":0.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.022","x":1.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>2</b>","x":-0.45,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"NFLX","x":0.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0297","x":1.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>3</b>","x":-0.45,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"GOOG","x":0.55,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0194","x":1.55,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>4</b>","x":-0.45,"xanchor":"left","xref":"x","y":5,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"BA","x":0.55,"xanchor":"left","xref":"x","y":5,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0319","x":1.55,"xanchor":"left","xref":"x","y":5,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>5</b>","x":-0.45,"xanchor":"left","xref":"x","y":6,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"V","x":0.55,"xanchor":"left","xref":"x","y":6,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0184","x":1.55,"xanchor":"left","xref":"x","y":6,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>6</b>","x":-0.45,"xanchor":"left","xref":"x","y":7,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"MA","x":0.55,"xanchor":"left","xref":"x","y":7,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0208","x":1.55,"xanchor":"left","xref":"x","y":7,"yref":"y"}],"h ...

# %%
# Density plot of the daily returns

sns.displot(data = daily_returns, kind = 'kde', aspect = 2.5)
plt.xlim(-0.2,0.2)
# Out:
# (-0.2, 0.2)

# %%
# Annual volatility for each asset

annual_volatility = daily_volatility.loc[:,"Daily Volatility"] * np.sqrt(252)

annual_volatility = pd.DataFrame({'Asset':daily_volatility.loc[:,"Asset"], 'Annual Volatility':annual_volatility.values})

plot_table(annual_volatility)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f44b6d86-8246-4c30-89bc-588100c4c911" class="plotly-graph-div" style="height:290px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f44b6d86-8246-4c30-89bc-588100c4c911")) {                    Plotly.newPlot(                        "f44b6d86-8246-4c30-89bc-588100c4c911",                        [{"colorscale":[[0,"#1a88ff"],[0.5,"#e6f2ff"],[1,"#ffffff"]],"hoverinfo":"none","opacity":0.75,"showscale":false,"z":[[0,0,0],[0,0.5,0.5],[0,1,1],[0,0.5,0.5],[0,1,1],[0,0.5,0.5],[0,1,1],[0,0.5,0.5]],"type":"heatmap"}],                        {"annotations":[{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b></b>","x":-0.45,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Asset</b>","x":0.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Annual Volatility</b>","x":1.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>0</b>","x":-0.45,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"META","x":0.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.4234","x":1.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>1</b>","x":-0.45,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"AMZN","x":0.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.35","x":1.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>2</b>","x":-0.45,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"NFLX","x":0.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.4707","x":1.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>3</b>","x":-0.45,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"GOOG","x":0.55,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.3076","x":1.55,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>4</b>","x":-0.45,"xanchor":"left","xref":"x","y":5,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"BA","x":0.55,"xanchor":"left","xref":"x","y":5,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.5062","x":1.55,"xanchor":"left","xref":"x","y":5,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>5</b>","x":-0.45,"xanchor":"left","xref":"x","y":6,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"V","x":0.55,"xanchor":"left","xref":"x","y":6,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.292","x":1.55,"xanchor":"left","xref":"x","y":6,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>6</b>","x":-0.45,"xanchor":"left","xref":"x","y":7,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"MA","x":0.55,"xanchor":"left","xref":"x","y":7,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.3298","x":1.55,"xanchor":"left","xref":"x","y":7,"yref":"y"}],"he ...

# %%
# Plot cumulative returns for each asset

daily_cum_returns = 1 + df.dropna().pct_change()
daily_cum_returns = daily_cum_returns.cumprod()*100

title = 'Cumulative returns for each asset'
xlabel = 'Date'
ylabel = 'Cumulative returns'

col = list(daily_cum_returns.columns.values)
plot_graph(col,title,xlabel,ylabel,daily_cum_returns)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9f84e825-e3e3-4e7b-a9a4-24eab945b8b3" class="plotly-graph-div" style="height:500px; width:690px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f84e825-e3e3-4e7b-a9a4-24eab945b8b3")) {                    Plotly.newPlot(                        "9f84e825-e3e3-4e7b-a9a4-24eab945b8b3",                        [{"name":"META","x":["2017-11-06T00:00:00","2017-11-07T00:00:00","2017-11-08T00:00:00","2017-11-09T00:00:00","2017-11-10T00:00:00","2017-11-13T00:00:00","2017-11-14T00:00:00","2017-11-15T00:00:00","2017-11-16T00:00:00","2017-11-17T00:00:00","2017-11-20T00:00:00","2017-11-21T00:00:00","2017-11-22T00:00:00","2017-11-24T00:00:00","2017-11-27T00:00:00","2017-11-28T00:00:00","2017-11-29T00:00:00","2017-11-30T00:00:00","2017-12-01T00:00:00","2017-12-04T00:00:00","2017-12-05T00:00:00","2017-12-06T00:00:00","2017-12-07T00:00:00","2017-12-08T00:00:00","2017-12-11T00:00:00","2017-12-12T00:00:00","2017-12-13T00:00:00","2017-12-14T00:00:00","2017-12-15T00:00:00","2017-12-18T00:00:00","2017-12-19T00:00:00","2017-12-20T00:00:00","2017-12-21T00:00:00","2017-12-22T00:00:00","2017-12-26T00:00:00","2017-12-27T00:00:00","2017-12-28T00:00:00","2017-12-29T00:00:00","2018-01-02T00:00:00","2018-01-03T00:00:00","2018-01-04T00:00:00","2018-01-05T00:00:00","2018-01-08T00:00:00","2018-01-09T00:00:00","2018-01-10T00:00:00","2018-01-11T00:00:00","2018-01-12T00:00:00","2018-01-16T00:00:00","2018-01-17T00:00:00","2018-01-18T00:00:00","2018-01-19T00:00:00","2018-01-22T00:00:00","2018-01-23T00:00:00","2018-01-24T00:00:00","2018-01-25T00:00:00","2018-01-26T00:00:00","2018-01-29T00:00:00","2018-01-30T00:00:00","2018-01-31T00:00:00","2018-02-01T00:00:00","2018-02-02T00:00:00","2018-02-05T00:00:00","2018-02-06T00:00:00","2018-02-07T00:00:00","2018-02-08T00:00:00","2018-02-09T00:00:00","2018-02-12T00:00:00","2018-02-13T00:00:00","2018-02-14T00:00:00","2018-02-15T00:00:00","2018-02-16T00:00:00","2018-02-20T00:00:00","2018-02-21T00:00:00","2018-02-22T00:00:00","2018-02-23T00:00:00","2018-02-26T00:00:00","2018-02-27T00:00:00","2018-02-28T00:00:00","2018-03-01T00:00:00","2018-03-02T00:00:00","2018-03-05T00:00:00","2018-03-06T00:00:00","2018-03-07T00:00:00","2018-03-08T00:00:00","2018-03-09T00:00:00","2018-03-12T00:00:00","2018-03-13T00:00:00","2018-03-14T00:00:00","2018-03-15T00:00:00","2018-03-16T00:00:00","2018-03-19T00:00:00","2018-03-20T00:00:00","2018-03-21T00:00:00","2018-03-22T00:00:00","2018-03-23T00:00:00","2018-03-26T00:00:00","2018-03-27T00:00:00","2018-03-28T00:00:00","2018-03-29T00:00:00","2018-04-02T00:00:00","2018-04-03T00:00:00","2018-04-04T00:00:00","2018-04-05T00:00:00","2018-04-06T00:00:00","2018-04-09T00:00:00","2018-04-10T00:00:00","2018-04-11T00:00:00","2018-04-12T00:00:00","2018-04-13T00:00:00","2018-04-16T00:00:00","2018-04-17T00:00:00","2018-04-18T00:00:00","2018-04-19T00:00:00","2018-04-20T00:00:00","2018-04-23T00:00:00","2018-04-24T00:00:00","2018-04-25T00:00:00","2018-04-26T00:00:00","2018-04-27T00:00:00","2018-04-30T00:00:00","2018-05-01T00:00:00","2018-05-02T00:00:00","2018-05-03T00:00:00","2018-05-04T00:00:00","2018-05-07T00:00:00","2018-05-08T00:00:00","2018-05-09T00:00:00","2018-05-10T00:00:00","2018-05-11T00:00:00","2018-05-14T00:00:00","2018-05-15T00:00:00","2018-05-16T00:00:00","2018-05-17T00:00:00","2018-05-18T00:00:00","2018-05-21T00:00:00","2018-05-22T00:00:00","2018-05-23T00:00:00","2018-05-24T00:00:00","2018-05-25T00:00:00","2018-05-29T00:00:00","2018-05-30T00:00:00","2018-05-31T00:00:00","2018-06-01T00:00:00","2018-06-04T00:00:00","2018-06-05T00:00:00","2018-06-06T00:00:00","2018-06-07T00:00:00","2018-06-08T00:00:00","2018-06-11T00:00:00","2018-06-12T00:00:00","2018-06-13T00:00:00","2018-06-14T00:00:00","2018-06-15T00:00:00","2018-06-18T00:00:00","2018-06-19T00:00:00","2018-06-20T00:00:00", ...

# %%
# Compute correlation matrix between assets

annual_cor_matrix = df.corr().round(3)

# plot_table(corr_df)

fig_corr = px.imshow(annual_cor_matrix, text_auto = True, title = 'Correlation matrix between assets')
fig_corr.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="61c1004a-1f8d-4666-b560-49e1c9704155" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("61c1004a-1f8d-4666-b560-49e1c9704155")) {                    Plotly.newPlot(                        "61c1004a-1f8d-4666-b560-49e1c9704155",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["META","AMZN","NFLX","GOOG","BA","V","MA"],"y":["META","AMZN","NFLX","GOOG","BA","V","MA"],"z":[[1.0,0.832,0.85,0.703,-0.326,0.709,0.682],[0.832,1.0,0.783,0.828,-0.629,0.882,0.879],[0.85,0.783,1.0,0.499,-0.228,0.559,0.539],[0.703,0.828,0.499,1.0,-0.598,0.836,0.828],[-0.326,-0.629,-0.228,-0.598,1.0,-0.586,-0.603],[0.709,0.882,0.559,0.836,-0.586,1.0,0.991],[0.682,0.879,0.539,0.828,-0.603,0.991,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}<br>y: %{y}<br>color: %{z}<extra></extra>"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{ ...

# %%
# Compute covariance matrix between assets

annual_cov_matrix = (daily_returns.cov() * 252).round(3)

# plot_table(annual_cov_matrix)

fig_cov = px.imshow(annual_cov_matrix, text_auto = True, title = 'Covariance matrix between assets')
fig_cov.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e44325f4-7026-40cb-bf37-cc06333c0830" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e44325f4-7026-40cb-bf37-cc06333c0830")) {                    Plotly.newPlot(                        "e44325f4-7026-40cb-bf37-cc06333c0830",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["META","AMZN","NFLX","GOOG","BA","V","MA"],"y":["META","AMZN","NFLX","GOOG","BA","V","MA"],"z":[[0.179,0.091,0.104,0.087,0.069,0.062,0.073],[0.091,0.122,0.101,0.073,0.057,0.051,0.06],[0.104,0.101,0.222,0.074,0.063,0.053,0.059],[0.087,0.073,0.074,0.095,0.069,0.058,0.065],[0.069,0.057,0.063,0.069,0.256,0.078,0.092],[0.062,0.051,0.053,0.058,0.078,0.085,0.088],[0.073,0.06,0.059,0.065,0.092,0.088,0.109]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}<br>y: %{y}<br>color: %{z}<extra></extra>"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords": ...

# %%
# Compute annual expected returns

annual_mean_returns = expected_returns.mean_historical_return(df)

annual_mean_returns_df = pd.DataFrame({'Asset':daily_volatility.loc[:,'Asset'], 'Annual Mean Returns':annual_mean_returns.values})

plot_table(annual_mean_returns_df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="422750c0-539c-4cf7-906e-b9708b23e7c1" class="plotly-graph-div" style="height:290px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("422750c0-539c-4cf7-906e-b9708b23e7c1")) {                    Plotly.newPlot(                        "422750c0-539c-4cf7-906e-b9708b23e7c1",                        [{"colorscale":[[0,"#1a88ff"],[0.5,"#e6f2ff"],[1,"#ffffff"]],"hoverinfo":"none","opacity":0.75,"showscale":false,"z":[[0,0,0],[0,0.5,0.5],[0,1,1],[0,0.5,0.5],[0,1,1],[0,0.5,0.5],[0,1,1],[0,0.5,0.5]],"type":"heatmap"}],                        {"annotations":[{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b></b>","x":-0.45,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Asset</b>","x":0.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Annual Mean Returns</b>","x":1.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>0</b>","x":-0.45,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"META","x":0.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"-0.132","x":1.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>1</b>","x":-0.45,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"AMZN","x":0.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0979","x":1.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>2</b>","x":-0.45,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"NFLX","x":0.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0611","x":1.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>3</b>","x":-0.45,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"GOOG","x":0.55,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.1026","x":1.55,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>4</b>","x":-0.45,"xanchor":"left","xref":"x","y":5,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"BA","x":0.55,"xanchor":"left","xref":"x","y":5,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"-0.0896","x":1.55,"xanchor":"left","xref":"x","y":5,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>5</b>","x":-0.45,"xanchor":"left","xref":"x","y":6,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"V","x":0.55,"xanchor":"left","xref":"x","y":6,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.1247","x":1.55,"xanchor":"left","xref":"x","y":6,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>6</b>","x":-0.45,"xanchor":"left","xref":"x","y":7,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"MA","x":0.55,"xanchor":"left","xref":"x","y":7,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.1622","x":1.55,"xanchor":"left","xref":"x","y":7,"yref":"y" ...

# %%
def plot_efficient_frontier_and_max_sharpe(mu, S):  
    # Optimize portfolio for maximal Sharpe ratio 
    ef = EfficientFrontier(mu, S)
    fig, ax = plt.subplots(figsize=(8,6))
    ef_max_sharpe = copy.deepcopy(ef)
    plotting.plot_efficient_frontier(ef, ax=ax, show_assets=True)
    # Find the max sharpe portfolio
    ef_max_sharpe.max_sharpe(risk_free_rate=0)
    ret_tangent, std_tangent, _ =   ef_max_sharpe.portfolio_performance(risk_free_rate=0)
    ax.scatter(std_tangent, ret_tangent, marker="*", s=100, c="r",     label="Max Sharpe Ratio")
# Generate random portfolios
    n_samples = 1000
    w = np.random.dirichlet(np.ones(ef.n_assets), n_samples)
    rets = w.dot(ef.expected_returns)
    stds = np.sqrt(np.diag(w @ ef.cov_matrix @ w.T))
    sharpes = rets / stds
    ax.scatter(stds, rets, marker=".", c=sharpes, cmap="viridis_r")
# Output
    ax.set_title("Efficient Frontier with Random Portfolios")
    ax.legend()
    plt.tight_layout()
    plt.show()
    
plot_efficient_frontier_and_max_sharpe(annual_mean_returns, annual_cov_matrix)

# %%
# Print portfolio's performance
# Equal weights on each asset

annual_returns_0, annual_variance_0, annual_sd_0 = portfolioPerformance(np.array(weights),
                                                                  np.array(annual_mean_returns),
                                                                  annual_cov_matrix.to_numpy())

sharpeRatio_0 = SR(np.array(weights), np.array(annual_mean_returns), annual_cov_matrix.to_numpy(), 0)

percent_ret = str(round(annual_returns_0, 2) * 100) + '%'
percent_var = str(round(annual_variance_0, 2) * 100) + '%'
percent_sd = str(round(annual_sd_0, 2) * 100 ) + '%'

print('Expected annual return        : ' + percent_ret)
print('Annual variance               : ' + percent_var)
print('Annual volatility / risk / sd : ' + percent_sd)
print('Sharpe ratio                  : ' + str(round(sharpeRatio_0, 2)))
# Out:
# Expected annual return        : 5.0%
# Annual variance               : 8.0%
# Annual volatility / risk / sd : 28.999999999999996%
# Sharpe ratio                  : 0.16

# %%
#############################################
# Optimize portfolio for minimum volatility #
#############################################

# %%
result = minVol(annual_cov_matrix.to_numpy(), (0,1))

minVolRes, weights_1 = result['fun'], result['x']

weights_1_df = pd.DataFrame({'Asset':daily_volatility.loc[:,'Asset'], 'Weights_1':weights_1})

weights_1_dict = dict(zip(assets, weights_1.T))

plot_table(weights_1_df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e463d2e4-cafb-4eac-9a53-2e592e8461d4" class="plotly-graph-div" style="height:290px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e463d2e4-cafb-4eac-9a53-2e592e8461d4")) {                    Plotly.newPlot(                        "e463d2e4-cafb-4eac-9a53-2e592e8461d4",                        [{"colorscale":[[0,"#1a88ff"],[0.5,"#e6f2ff"],[1,"#ffffff"]],"hoverinfo":"none","opacity":0.75,"showscale":false,"z":[[0,0,0],[0,0.5,0.5],[0,1,1],[0,0.5,0.5],[0,1,1],[0,0.5,0.5],[0,1,1],[0,0.5,0.5]],"type":"heatmap"}],                        {"annotations":[{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b></b>","x":-0.45,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Asset</b>","x":0.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Weights_1</b>","x":1.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>0</b>","x":-0.45,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"META","x":0.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0","x":1.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>1</b>","x":-0.45,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"AMZN","x":0.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.1836","x":1.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>2</b>","x":-0.45,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"NFLX","x":0.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0214","x":1.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>3</b>","x":-0.45,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"GOOG","x":0.55,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.2655","x":1.55,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>4</b>","x":-0.45,"xanchor":"left","xref":"x","y":5,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"BA","x":0.55,"xanchor":"left","xref":"x","y":5,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0","x":1.55,"xanchor":"left","xref":"x","y":5,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>5</b>","x":-0.45,"xanchor":"left","xref":"x","y":6,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"V","x":0.55,"xanchor":"left","xref":"x","y":6,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.5294","x":1.55,"xanchor":"left","xref":"x","y":6,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>6</b>","x":-0.45,"xanchor":"left","xref":"x","y":7,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"MA","x":0.55,"xanchor":"left","xref":"x","y":7,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0","x":1.55,"xanchor":"left","xref":"x","y":7,"yref":"y"}],"height":290,"mar ...

# %%
# Print portfolio's performance

annual_returns_1, annual_variance_1, annual_sd_1 = portfolioPerformance(np.array(weights_1),
                                                                        np.array(annual_mean_returns),
                                                                        annual_cov_matrix.to_numpy())

sharpeRatio_1 = SR(np.array(weights_1), np.array(annual_mean_returns), annual_cov_matrix.to_numpy(), 0)

percent_ret = str(round(annual_returns_1, 2) * 100) + '%'
percent_sd = str(round(annual_sd_1, 2) * 100 ) + '%'

print('Expected annual return        : ' + percent_ret)
print('Annual volatility / risk / sd : ' + percent_sd)
print('Sharpe ratio                  : ' + str(round(sharpeRatio_1, 2)))
# Out:
# Expected annual return        : 11.0%
# Annual volatility / risk / sd : 27.0%
# Sharpe ratio                  : 0.42

# %%
# Generate Portfolio with Optimized Weights

# Now let us generate the portfolio with optimized weights and plot out its cumulative returns over time.

my_assets_1 = my_assets.copy(deep=True)
my_assets_1['Optimized Portfolio'] = 0
for asset, weight in weights_1_dict.items():
    my_assets_1['Optimized Portfolio'] += my_assets_1[asset]*weight

my_assets_1
# Out:
#                   META        AMZN        NFLX       GOOG          BA  \
# Date
# 2017-11-06  180.169998   56.033001  200.130005  51.294998  250.311203
# 2017-11-07  180.250000   56.158501  195.889999  51.666500  252.263916
# 2017-11-08  179.559998   56.644001  196.440002  51.992500  251.733032
# 2017-11-09  179.300003   56.456501  193.899994  51.563000  250.351257
# 2017-11-10  178.460007   56.267502  192.020004  51.403500  248.588196
# ...                ...         ...         ...        ...         ...
# 2022-10-28   99.199997  103.410004  295.720001  96.580002  143.839996
# 2022-10-31   93.160004  102.440002  291.880005  94.660004  142.509995
# 2022-11-01   95.199997   96.790001  286.750000  90.500000  143.380005
# 2022-11-02   90.540001   92.120003  273.000000  87.070000  147.410004
# 2022-11-03   88.910004   89.300003  269.059998  83.489998  156.750000
#
#                      V          MA  Optimized Portfolio
# Date
# 2017-11-06  108.355034  146.081161            85.562596
# 2017-11-07  108.519608  145.964355            85.680603
# 2017-11-08  108.887527  145.964355            86.062885
# 2017-11-09  108.568031  145.302521            85.690867
# 2017-11-10  108.316322  145.545807            85.440284
# ...                ...         ...                  ...
# 2022-10-28  209.339996  329.470001           161.799043
# 2022-10-31  207.160004  328.179993           159.874731
# 2022-11-01  206.929993  333.190002           157.501034
# 2022-11-02  200.949997  319.820007           152.272228
# 2022-11-03  194.750000  309.170013           147.436947
#
# [1258 rows x 8 columns]

# %%
# Plot cumulative returns for each asset

my_df = my_assets_1[['Optimized Portfolio']]
daily_cum_returns_opt = 1 + my_df.dropna().pct_change()
daily_cum_returns_opt = daily_cum_returns_opt.cumprod()*100

title = 'Cumulative Returns of Optimized Portfolio Starting with $100'
xlabel = 'Date'
ylabel = 'Cumulative returns'

col = list(daily_cum_returns_opt.dropna())
plot_graph(col,title,xlabel,ylabel,daily_cum_returns_opt.dropna())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="491cef66-85f5-4be4-ac41-89a2c3b52a5c" class="plotly-graph-div" style="height:500px; width:690px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("491cef66-85f5-4be4-ac41-89a2c3b52a5c")) {                    Plotly.newPlot(                        "491cef66-85f5-4be4-ac41-89a2c3b52a5c",                        [{"name":"Optimized Portfolio","x":["2017-11-07T00:00:00","2017-11-08T00:00:00","2017-11-09T00:00:00","2017-11-10T00:00:00","2017-11-13T00:00:00","2017-11-14T00:00:00","2017-11-15T00:00:00","2017-11-16T00:00:00","2017-11-17T00:00:00","2017-11-20T00:00:00","2017-11-21T00:00:00","2017-11-22T00:00:00","2017-11-24T00:00:00","2017-11-27T00:00:00","2017-11-28T00:00:00","2017-11-29T00:00:00","2017-11-30T00:00:00","2017-12-01T00:00:00","2017-12-04T00:00:00","2017-12-05T00:00:00","2017-12-06T00:00:00","2017-12-07T00:00:00","2017-12-08T00:00:00","2017-12-11T00:00:00","2017-12-12T00:00:00","2017-12-13T00:00:00","2017-12-14T00:00:00","2017-12-15T00:00:00","2017-12-18T00:00:00","2017-12-19T00:00:00","2017-12-20T00:00:00","2017-12-21T00:00:00","2017-12-22T00:00:00","2017-12-26T00:00:00","2017-12-27T00:00:00","2017-12-28T00:00:00","2017-12-29T00:00:00","2018-01-02T00:00:00","2018-01-03T00:00:00","2018-01-04T00:00:00","2018-01-05T00:00:00","2018-01-08T00:00:00","2018-01-09T00:00:00","2018-01-10T00:00:00","2018-01-11T00:00:00","2018-01-12T00:00:00","2018-01-16T00:00:00","2018-01-17T00:00:00","2018-01-18T00:00:00","2018-01-19T00:00:00","2018-01-22T00:00:00","2018-01-23T00:00:00","2018-01-24T00:00:00","2018-01-25T00:00:00","2018-01-26T00:00:00","2018-01-29T00:00:00","2018-01-30T00:00:00","2018-01-31T00:00:00","2018-02-01T00:00:00","2018-02-02T00:00:00","2018-02-05T00:00:00","2018-02-06T00:00:00","2018-02-07T00:00:00","2018-02-08T00:00:00","2018-02-09T00:00:00","2018-02-12T00:00:00","2018-02-13T00:00:00","2018-02-14T00:00:00","2018-02-15T00:00:00","2018-02-16T00:00:00","2018-02-20T00:00:00","2018-02-21T00:00:00","2018-02-22T00:00:00","2018-02-23T00:00:00","2018-02-26T00:00:00","2018-02-27T00:00:00","2018-02-28T00:00:00","2018-03-01T00:00:00","2018-03-02T00:00:00","2018-03-05T00:00:00","2018-03-06T00:00:00","2018-03-07T00:00:00","2018-03-08T00:00:00","2018-03-09T00:00:00","2018-03-12T00:00:00","2018-03-13T00:00:00","2018-03-14T00:00:00","2018-03-15T00:00:00","2018-03-16T00:00:00","2018-03-19T00:00:00","2018-03-20T00:00:00","2018-03-21T00:00:00","2018-03-22T00:00:00","2018-03-23T00:00:00","2018-03-26T00:00:00","2018-03-27T00:00:00","2018-03-28T00:00:00","2018-03-29T00:00:00","2018-04-02T00:00:00","2018-04-03T00:00:00","2018-04-04T00:00:00","2018-04-05T00:00:00","2018-04-06T00:00:00","2018-04-09T00:00:00","2018-04-10T00:00:00","2018-04-11T00:00:00","2018-04-12T00:00:00","2018-04-13T00:00:00","2018-04-16T00:00:00","2018-04-17T00:00:00","2018-04-18T00:00:00","2018-04-19T00:00:00","2018-04-20T00:00:00","2018-04-23T00:00:00","2018-04-24T00:00:00","2018-04-25T00:00:00","2018-04-26T00:00:00","2018-04-27T00:00:00","2018-04-30T00:00:00","2018-05-01T00:00:00","2018-05-02T00:00:00","2018-05-03T00:00:00","2018-05-04T00:00:00","2018-05-07T00:00:00","2018-05-08T00:00:00","2018-05-09T00:00:00","2018-05-10T00:00:00","2018-05-11T00:00:00","2018-05-14T00:00:00","2018-05-15T00:00:00","2018-05-16T00:00:00","2018-05-17T00:00:00","2018-05-18T00:00:00","2018-05-21T00:00:00","2018-05-22T00:00:00","2018-05-23T00:00:00","2018-05-24T00:00:00","2018-05-25T00:00:00","2018-05-29T00:00:00","2018-05-30T00:00:00","2018-05-31T00:00:00","2018-06-01T00:00:00","2018-06-04T00:00:00","2018-06-05T00:00:00","2018-06-06T00:00:00","2018-06-07T00:00:00","2018-06-08T00:00:00","2018-06-11T00:00:00","2018-06-12T00:00:00","2018-06-13T00:00:00","2018-06-14T00:00:00","2018-06-15T00:00:00","2018-06-18T00:00:00","2018-06-19T00:00:00","2018-06-20T00:00:00","2018-0 ...

# %%
# Get the discrete allocation of each share per stock

latest_prices = get_latest_prices(my_assets)
da = DiscreteAllocation(weights_1_dict, latest_prices, total_portfolio_value = 10000)

allocation, leftover = da.lp_portfolio()

print('Latest prices of assets:\n')

print(latest_prices)
print ('\nDiscrete allocation:',allocation)
print('Funds remaining: ${:.2f}'.format (leftover))
# Out:
# Latest prices of assets:
#
# META     88.910004
# AMZN     89.300003
# NFLX    269.059998
# GOOG     83.489998
# BA      156.750000
# V       194.750000
# MA      309.170013
# Name: 2022-11-03 00:00:00, dtype: float64
#
# Discrete allocation: {'AMZN': 20, 'NFLX': 1, 'GOOG': 32, 'V': 27}
# Funds remaining: $15.01

# %%
###############################################
# Optimize portfolio for maximum Sharpe ratio #
###############################################

# %%
result = maxSR(np.array(annual_mean_returns), annual_cov_matrix.to_numpy(), 0, (0,1))

maxSRRes, weights_2 = result['fun'], result['x']

weights_2_df = pd.DataFrame({'Asset':daily_volatility.loc[:,'Asset'], 'Weights_2':weights_2})

weights_2_dict = dict(zip(assets, weights_2.T))

plot_table(weights_2_df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e928c271-5cfb-43a3-9746-557cc11b1ec3" class="plotly-graph-div" style="height:290px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e928c271-5cfb-43a3-9746-557cc11b1ec3")) {                    Plotly.newPlot(                        "e928c271-5cfb-43a3-9746-557cc11b1ec3",                        [{"colorscale":[[0,"#1a88ff"],[0.5,"#e6f2ff"],[1,"#ffffff"]],"hoverinfo":"none","opacity":0.75,"showscale":false,"z":[[0,0,0],[0,0.5,0.5],[0,1,1],[0,0.5,0.5],[0,1,1],[0,0.5,0.5],[0,1,1],[0,0.5,0.5]],"type":"heatmap"}],                        {"annotations":[{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b></b>","x":-0.45,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Asset</b>","x":0.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Weights_2</b>","x":1.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>0</b>","x":-0.45,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"META","x":0.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0","x":1.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>1</b>","x":-0.45,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"AMZN","x":0.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0478","x":1.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>2</b>","x":-0.45,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"NFLX","x":0.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0","x":1.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>3</b>","x":-0.45,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"GOOG","x":0.55,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0361","x":1.55,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>4</b>","x":-0.45,"xanchor":"left","xref":"x","y":5,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"BA","x":0.55,"xanchor":"left","xref":"x","y":5,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0","x":1.55,"xanchor":"left","xref":"x","y":5,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>5</b>","x":-0.45,"xanchor":"left","xref":"x","y":6,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"V","x":0.55,"xanchor":"left","xref":"x","y":6,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0","x":1.55,"xanchor":"left","xref":"x","y":6,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>6</b>","x":-0.45,"xanchor":"left","xref":"x","y":7,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"MA","x":0.55,"xanchor":"left","xref":"x","y":7,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.9161","x":1.55,"xanchor":"left","xref":"x","y":7,"yref":"y"}],"height":290,"margin ...

# %%
# Print portfolio's performance

annual_returns_2, annual_variance_2, annual_sd_2 = portfolioPerformance(np.array(weights_2),
                                                                        np.array(annual_mean_returns),
                                                                        annual_cov_matrix.to_numpy())

sharpeRatio_2 = SR(np.array(weights_2), np.array(annual_mean_returns), annual_cov_matrix.to_numpy(), 0)

percent_ret = str(round(annual_returns_2, 2) * 100) + '%'
percent_sd = str(round(annual_sd_2, 2) * 100 ) + '%'

print('Expected annual return        : ' + percent_ret)
print('Annual volatility / risk / sd : ' + percent_sd)
print('Sharpe ratio                  : ' + str(round(sharpeRatio_2, 2)))
# Out:
# Expected annual return        : 16.0%
# Annual volatility / risk / sd : 32.0%
# Sharpe ratio                  : 0.49

# %%
# Generate Portfolio with Optimized Weights

# Now let us generate the portfolio with optimized weights and plot out its cumulative returns over time.

my_assets_2 = my_assets.copy(deep=True)
my_assets_2['Optimized Portfolio'] = 0
for asset, weight in weights_2_dict.items():
    my_assets_2['Optimized Portfolio'] += my_assets_2[asset]*weight

my_assets_2
# Out:
#                   META        AMZN        NFLX       GOOG          BA  \
# Date
# 2017-11-06  180.169998   56.033001  200.130005  51.294998  250.311203
# 2017-11-07  180.250000   56.158501  195.889999  51.666500  252.263916
# 2017-11-08  179.559998   56.644001  196.440002  51.992500  251.733032
# 2017-11-09  179.300003   56.456501  193.899994  51.563000  250.351257
# 2017-11-10  178.460007   56.267502  192.020004  51.403500  248.588196
# ...                ...         ...         ...        ...         ...
# 2022-10-28   99.199997  103.410004  295.720001  96.580002  143.839996
# 2022-10-31   93.160004  102.440002  291.880005  94.660004  142.509995
# 2022-11-01   95.199997   96.790001  286.750000  90.500000  143.380005
# 2022-11-02   90.540001   92.120003  273.000000  87.070000  147.410004
# 2022-11-03   88.910004   89.300003  269.059998  83.489998  156.750000
#
#                      V          MA  Optimized Portfolio
# Date
# 2017-11-06  108.355034  146.081161           138.356867
# 2017-11-07  108.519608  145.964355           138.269267
# 2017-11-08  108.887527  145.964355           138.304233
# 2017-11-09  108.568031  145.302521           137.673448
# 2017-11-10  108.316322  145.545807           137.881539
# ...                ...         ...                  ...
# 2022-10-28  209.339996  329.470001           310.261510
# 2022-10-31  207.160004  328.179993           308.964046
# 2022-11-01  206.929993  333.190002           313.133688
# 2022-11-02  200.949997  319.820007           300.538217
# 2022-11-03  194.750000  309.170013           290.517564
#
# [1258 rows x 8 columns]

# %%
# Plot cumulative returns for each asset

my_df = my_assets_2[['Optimized Portfolio']]
daily_cum_returns_opt = 1 + my_df.dropna().pct_change()
daily_cum_returns_opt = daily_cum_returns_opt.cumprod()*100

title = 'Cumulative Returns of Optimized Portfolio Starting with $100'
xlabel = 'Date'
ylabel = 'Cumulative returns'

col = list(daily_cum_returns_opt.dropna())
plot_graph(col,title,xlabel,ylabel,daily_cum_returns_opt.dropna())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b1610f4f-9d7c-4cf0-8b30-47d5fb4712dc" class="plotly-graph-div" style="height:500px; width:690px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b1610f4f-9d7c-4cf0-8b30-47d5fb4712dc")) {                    Plotly.newPlot(                        "b1610f4f-9d7c-4cf0-8b30-47d5fb4712dc",                        [{"name":"Optimized Portfolio","x":["2017-11-07T00:00:00","2017-11-08T00:00:00","2017-11-09T00:00:00","2017-11-10T00:00:00","2017-11-13T00:00:00","2017-11-14T00:00:00","2017-11-15T00:00:00","2017-11-16T00:00:00","2017-11-17T00:00:00","2017-11-20T00:00:00","2017-11-21T00:00:00","2017-11-22T00:00:00","2017-11-24T00:00:00","2017-11-27T00:00:00","2017-11-28T00:00:00","2017-11-29T00:00:00","2017-11-30T00:00:00","2017-12-01T00:00:00","2017-12-04T00:00:00","2017-12-05T00:00:00","2017-12-06T00:00:00","2017-12-07T00:00:00","2017-12-08T00:00:00","2017-12-11T00:00:00","2017-12-12T00:00:00","2017-12-13T00:00:00","2017-12-14T00:00:00","2017-12-15T00:00:00","2017-12-18T00:00:00","2017-12-19T00:00:00","2017-12-20T00:00:00","2017-12-21T00:00:00","2017-12-22T00:00:00","2017-12-26T00:00:00","2017-12-27T00:00:00","2017-12-28T00:00:00","2017-12-29T00:00:00","2018-01-02T00:00:00","2018-01-03T00:00:00","2018-01-04T00:00:00","2018-01-05T00:00:00","2018-01-08T00:00:00","2018-01-09T00:00:00","2018-01-10T00:00:00","2018-01-11T00:00:00","2018-01-12T00:00:00","2018-01-16T00:00:00","2018-01-17T00:00:00","2018-01-18T00:00:00","2018-01-19T00:00:00","2018-01-22T00:00:00","2018-01-23T00:00:00","2018-01-24T00:00:00","2018-01-25T00:00:00","2018-01-26T00:00:00","2018-01-29T00:00:00","2018-01-30T00:00:00","2018-01-31T00:00:00","2018-02-01T00:00:00","2018-02-02T00:00:00","2018-02-05T00:00:00","2018-02-06T00:00:00","2018-02-07T00:00:00","2018-02-08T00:00:00","2018-02-09T00:00:00","2018-02-12T00:00:00","2018-02-13T00:00:00","2018-02-14T00:00:00","2018-02-15T00:00:00","2018-02-16T00:00:00","2018-02-20T00:00:00","2018-02-21T00:00:00","2018-02-22T00:00:00","2018-02-23T00:00:00","2018-02-26T00:00:00","2018-02-27T00:00:00","2018-02-28T00:00:00","2018-03-01T00:00:00","2018-03-02T00:00:00","2018-03-05T00:00:00","2018-03-06T00:00:00","2018-03-07T00:00:00","2018-03-08T00:00:00","2018-03-09T00:00:00","2018-03-12T00:00:00","2018-03-13T00:00:00","2018-03-14T00:00:00","2018-03-15T00:00:00","2018-03-16T00:00:00","2018-03-19T00:00:00","2018-03-20T00:00:00","2018-03-21T00:00:00","2018-03-22T00:00:00","2018-03-23T00:00:00","2018-03-26T00:00:00","2018-03-27T00:00:00","2018-03-28T00:00:00","2018-03-29T00:00:00","2018-04-02T00:00:00","2018-04-03T00:00:00","2018-04-04T00:00:00","2018-04-05T00:00:00","2018-04-06T00:00:00","2018-04-09T00:00:00","2018-04-10T00:00:00","2018-04-11T00:00:00","2018-04-12T00:00:00","2018-04-13T00:00:00","2018-04-16T00:00:00","2018-04-17T00:00:00","2018-04-18T00:00:00","2018-04-19T00:00:00","2018-04-20T00:00:00","2018-04-23T00:00:00","2018-04-24T00:00:00","2018-04-25T00:00:00","2018-04-26T00:00:00","2018-04-27T00:00:00","2018-04-30T00:00:00","2018-05-01T00:00:00","2018-05-02T00:00:00","2018-05-03T00:00:00","2018-05-04T00:00:00","2018-05-07T00:00:00","2018-05-08T00:00:00","2018-05-09T00:00:00","2018-05-10T00:00:00","2018-05-11T00:00:00","2018-05-14T00:00:00","2018-05-15T00:00:00","2018-05-16T00:00:00","2018-05-17T00:00:00","2018-05-18T00:00:00","2018-05-21T00:00:00","2018-05-22T00:00:00","2018-05-23T00:00:00","2018-05-24T00:00:00","2018-05-25T00:00:00","2018-05-29T00:00:00","2018-05-30T00:00:00","2018-05-31T00:00:00","2018-06-01T00:00:00","2018-06-04T00:00:00","2018-06-05T00:00:00","2018-06-06T00:00:00","2018-06-07T00:00:00","2018-06-08T00:00:00","2018-06-11T00:00:00","2018-06-12T00:00:00","2018-06-13T00:00:00","2018-06-14T00:00:00","2018-06-15T00:00:00","2018-06-18T00:00:00","2018-06-19T00:00:00","2018-06-20T00:00:00","2018-0 ...

# %%
# Get the discrete allocation of each share per stock

latest_prices = get_latest_prices(my_assets)
da = DiscreteAllocation(weights_2_dict, latest_prices, total_portfolio_value = 10000)

allocation, leftover = da.lp_portfolio()

print('Latest prices of assets:\n')

print(latest_prices)
print ('\nDiscrete allocation:',allocation)
print('Funds remaining: ${:.2f}'.format (leftover))
# Out:
# Latest prices of assets:
#
# META     88.910004
# AMZN     89.300003
# NFLX    269.059998
# GOOG     83.489998
# BA      156.750000
# V       194.750000
# MA      309.170013
# Name: 2022-11-03 00:00:00, dtype: float64
#
# Discrete allocation: {'AMZN': 5, 'GOOG': 3, 'MA': 30}
# Funds remaining: $27.93

# %%
###################################################################
# Optimize portfolio by maximizing return for a given target risk #
###################################################################

# %%
result = efRetOnTargetRisk(0.3, np.array(annual_mean_returns), annual_cov_matrix.to_numpy(), (0,1))

efRetOnTargetRiskRes, weights_3 = result['fun'], result['x']

weights_3_df = pd.DataFrame({'Asset':daily_volatility.loc[:,'Asset'], 'Weights_3':weights_3})

weights_3_dict = dict(zip(assets, weights_3.T))

plot_table(weights_3_df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ebfe0d7a-6051-421e-873f-74029ebaa8dd" class="plotly-graph-div" style="height:290px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ebfe0d7a-6051-421e-873f-74029ebaa8dd")) {                    Plotly.newPlot(                        "ebfe0d7a-6051-421e-873f-74029ebaa8dd",                        [{"colorscale":[[0,"#1a88ff"],[0.5,"#e6f2ff"],[1,"#ffffff"]],"hoverinfo":"none","opacity":0.75,"showscale":false,"z":[[0,0,0],[0,0.5,0.5],[0,1,1],[0,0.5,0.5],[0,1,1],[0,0.5,0.5],[0,1,1],[0,0.5,0.5]],"type":"heatmap"}],                        {"annotations":[{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b></b>","x":-0.45,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Asset</b>","x":0.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Weights_3</b>","x":1.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>0</b>","x":-0.45,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"META","x":0.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0","x":1.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>1</b>","x":-0.45,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"AMZN","x":0.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0985","x":1.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>2</b>","x":-0.45,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"NFLX","x":0.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0","x":1.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>3</b>","x":-0.45,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"GOOG","x":0.55,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.1411","x":1.55,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>4</b>","x":-0.45,"xanchor":"left","xref":"x","y":5,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"BA","x":0.55,"xanchor":"left","xref":"x","y":5,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0","x":1.55,"xanchor":"left","xref":"x","y":5,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>5</b>","x":-0.45,"xanchor":"left","xref":"x","y":6,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"V","x":0.55,"xanchor":"left","xref":"x","y":6,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0303","x":1.55,"xanchor":"left","xref":"x","y":6,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>6</b>","x":-0.45,"xanchor":"left","xref":"x","y":7,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"MA","x":0.55,"xanchor":"left","xref":"x","y":7,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.7301","x":1.55,"xanchor":"left","xref":"x","y":7,"yref":"y"}],"height":290,"mar ...

# %%
# Print portfolio's performance

annual_returns_3, annual_variance_3, annual_sd_3 = portfolioPerformance(np.array(weights_3),
                                                                        np.array(annual_mean_returns),
                                                                        annual_cov_matrix.to_numpy())

sharpeRatio_3 = SR(np.array(weights_3), np.array(annual_mean_returns), annual_cov_matrix.to_numpy(), 0)

percent_ret = str(round(annual_returns_3, 2) * 100) + '%'
percent_sd = str(round(annual_sd_3, 2) * 100 ) + '%'

print('Expected annual return        : ' + percent_ret)
print('Annual volatility / risk / sd : ' + percent_sd)
print('Sharpe ratio                  : ' + str(round(sharpeRatio_3, 2)))
# Out:
# Expected annual return        : 15.0%
# Annual volatility / risk / sd : 30.0%
# Sharpe ratio                  : 0.49

# %%
# Generate Portfolio with Optimized Weights

# Now let us generate the portfolio with optimized weights and plot out its cumulative returns over time.

my_assets_3 = my_assets.copy(deep=True)
my_assets_3['Optimized Portfolio'] = 0
for asset, weight in weights_3_dict.items():
    my_assets_3['Optimized Portfolio'] += my_assets_3[asset]*weight

my_assets_3
# Out:
#                   META        AMZN        NFLX       GOOG          BA  \
# Date
# 2017-11-06  180.169998   56.033001  200.130005  51.294998  250.311203
# 2017-11-07  180.250000   56.158501  195.889999  51.666500  252.263916
# 2017-11-08  179.559998   56.644001  196.440002  51.992500  251.733032
# 2017-11-09  179.300003   56.456501  193.899994  51.563000  250.351257
# 2017-11-10  178.460007   56.267502  192.020004  51.403500  248.588196
# ...                ...         ...         ...        ...         ...
# 2022-10-28   99.199997  103.410004  295.720001  96.580002  143.839996
# 2022-10-31   93.160004  102.440002  291.880005  94.660004  142.509995
# 2022-11-01   95.199997   96.790001  286.750000  90.500000  143.380005
# 2022-11-02   90.540001   92.120003  273.000000  87.070000  147.410004
# 2022-11-03   88.910004   89.300003  269.059998  83.489998  156.750000
#
#                      V          MA  Optimized Portfolio
# Date
# 2017-11-06  108.355034  146.081161           122.693544
# 2017-11-07  108.519608  145.964355           122.678041
# 2017-11-08  108.887527  145.964355           122.783006
# 2017-11-09  108.568031  145.302521           122.211042
# 2017-11-10  108.316322  145.545807           122.339915
# ...                ...         ...                  ...
# 2022-10-28  209.339996  329.470001           270.701337
# 2022-10-31  207.160004  328.179993           269.326956
# 2022-11-01  206.929993  333.190002           271.834307
# 2022-11-02  200.949997  319.820007           260.947795
# 2022-11-03  194.750000  309.170013           252.201469
#
# [1258 rows x 8 columns]

# %%
# Plot cumulative returns for each asset

my_df = my_assets_3[['Optimized Portfolio']]
daily_cum_returns_opt = 1 + my_df.dropna().pct_change()
daily_cum_returns_opt = daily_cum_returns_opt.cumprod()*100

title = 'Cumulative Returns of Optimized Portfolio Starting with $100'
xlabel = 'Date'
ylabel = 'Cumulative returns'

col = list(daily_cum_returns_opt.dropna())
plot_graph(col,title,xlabel,ylabel,daily_cum_returns_opt.dropna())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="239e6cd0-d05a-4996-bc55-a1e24ac10949" class="plotly-graph-div" style="height:500px; width:690px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("239e6cd0-d05a-4996-bc55-a1e24ac10949")) {                    Plotly.newPlot(                        "239e6cd0-d05a-4996-bc55-a1e24ac10949",                        [{"name":"Optimized Portfolio","x":["2017-11-07T00:00:00","2017-11-08T00:00:00","2017-11-09T00:00:00","2017-11-10T00:00:00","2017-11-13T00:00:00","2017-11-14T00:00:00","2017-11-15T00:00:00","2017-11-16T00:00:00","2017-11-17T00:00:00","2017-11-20T00:00:00","2017-11-21T00:00:00","2017-11-22T00:00:00","2017-11-24T00:00:00","2017-11-27T00:00:00","2017-11-28T00:00:00","2017-11-29T00:00:00","2017-11-30T00:00:00","2017-12-01T00:00:00","2017-12-04T00:00:00","2017-12-05T00:00:00","2017-12-06T00:00:00","2017-12-07T00:00:00","2017-12-08T00:00:00","2017-12-11T00:00:00","2017-12-12T00:00:00","2017-12-13T00:00:00","2017-12-14T00:00:00","2017-12-15T00:00:00","2017-12-18T00:00:00","2017-12-19T00:00:00","2017-12-20T00:00:00","2017-12-21T00:00:00","2017-12-22T00:00:00","2017-12-26T00:00:00","2017-12-27T00:00:00","2017-12-28T00:00:00","2017-12-29T00:00:00","2018-01-02T00:00:00","2018-01-03T00:00:00","2018-01-04T00:00:00","2018-01-05T00:00:00","2018-01-08T00:00:00","2018-01-09T00:00:00","2018-01-10T00:00:00","2018-01-11T00:00:00","2018-01-12T00:00:00","2018-01-16T00:00:00","2018-01-17T00:00:00","2018-01-18T00:00:00","2018-01-19T00:00:00","2018-01-22T00:00:00","2018-01-23T00:00:00","2018-01-24T00:00:00","2018-01-25T00:00:00","2018-01-26T00:00:00","2018-01-29T00:00:00","2018-01-30T00:00:00","2018-01-31T00:00:00","2018-02-01T00:00:00","2018-02-02T00:00:00","2018-02-05T00:00:00","2018-02-06T00:00:00","2018-02-07T00:00:00","2018-02-08T00:00:00","2018-02-09T00:00:00","2018-02-12T00:00:00","2018-02-13T00:00:00","2018-02-14T00:00:00","2018-02-15T00:00:00","2018-02-16T00:00:00","2018-02-20T00:00:00","2018-02-21T00:00:00","2018-02-22T00:00:00","2018-02-23T00:00:00","2018-02-26T00:00:00","2018-02-27T00:00:00","2018-02-28T00:00:00","2018-03-01T00:00:00","2018-03-02T00:00:00","2018-03-05T00:00:00","2018-03-06T00:00:00","2018-03-07T00:00:00","2018-03-08T00:00:00","2018-03-09T00:00:00","2018-03-12T00:00:00","2018-03-13T00:00:00","2018-03-14T00:00:00","2018-03-15T00:00:00","2018-03-16T00:00:00","2018-03-19T00:00:00","2018-03-20T00:00:00","2018-03-21T00:00:00","2018-03-22T00:00:00","2018-03-23T00:00:00","2018-03-26T00:00:00","2018-03-27T00:00:00","2018-03-28T00:00:00","2018-03-29T00:00:00","2018-04-02T00:00:00","2018-04-03T00:00:00","2018-04-04T00:00:00","2018-04-05T00:00:00","2018-04-06T00:00:00","2018-04-09T00:00:00","2018-04-10T00:00:00","2018-04-11T00:00:00","2018-04-12T00:00:00","2018-04-13T00:00:00","2018-04-16T00:00:00","2018-04-17T00:00:00","2018-04-18T00:00:00","2018-04-19T00:00:00","2018-04-20T00:00:00","2018-04-23T00:00:00","2018-04-24T00:00:00","2018-04-25T00:00:00","2018-04-26T00:00:00","2018-04-27T00:00:00","2018-04-30T00:00:00","2018-05-01T00:00:00","2018-05-02T00:00:00","2018-05-03T00:00:00","2018-05-04T00:00:00","2018-05-07T00:00:00","2018-05-08T00:00:00","2018-05-09T00:00:00","2018-05-10T00:00:00","2018-05-11T00:00:00","2018-05-14T00:00:00","2018-05-15T00:00:00","2018-05-16T00:00:00","2018-05-17T00:00:00","2018-05-18T00:00:00","2018-05-21T00:00:00","2018-05-22T00:00:00","2018-05-23T00:00:00","2018-05-24T00:00:00","2018-05-25T00:00:00","2018-05-29T00:00:00","2018-05-30T00:00:00","2018-05-31T00:00:00","2018-06-01T00:00:00","2018-06-04T00:00:00","2018-06-05T00:00:00","2018-06-06T00:00:00","2018-06-07T00:00:00","2018-06-08T00:00:00","2018-06-11T00:00:00","2018-06-12T00:00:00","2018-06-13T00:00:00","2018-06-14T00:00:00","2018-06-15T00:00:00","2018-06-18T00:00:00","2018-06-19T00:00:00","2018-06-20T00:00:00","2018-0 ...

# %%
# Get the discrete allocation of each share per stock

latest_prices = get_latest_prices(my_assets)
da = DiscreteAllocation(weights_3_dict, latest_prices, total_portfolio_value = 10000)

allocation, leftover = da.lp_portfolio()

print('Latest prices of assets:\n')

print(latest_prices)
print ('\nDiscrete allocation:',allocation)
print('Funds remaining: ${:.2f}'.format (leftover))
# Out:
# Latest prices of assets:
#
# META     88.910004
# AMZN     89.300003
# NFLX    269.059998
# GOOG     83.489998
# BA      156.750000
# V       194.750000
# MA      309.170013
# Name: 2022-11-03 00:00:00, dtype: float64
#
# Discrete allocation: {'AMZN': 11, 'GOOG': 16, 'V': 1, 'MA': 24}
# Funds remaining: $67.03

# %%
###################################################################
# Optimize portfolio by minimizing risk for a given target return #
###################################################################

# %%
result = efRiskOnTargetReturn(0.15, np.array(annual_mean_returns), annual_cov_matrix.to_numpy(), (0,1))

efRiskOnTargetReturnRes, weights_4 = result['fun'], result['x']

weights_4_df = pd.DataFrame({'Asset':daily_volatility.loc[:,'Asset'], 'Weights_4':weights_4})

weights_4_dict = dict(zip(assets, weights_4.T))

plot_table(weights_4_df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1a1c0b48-222f-464d-85a0-b039e332a413" class="plotly-graph-div" style="height:290px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a1c0b48-222f-464d-85a0-b039e332a413")) {                    Plotly.newPlot(                        "1a1c0b48-222f-464d-85a0-b039e332a413",                        [{"colorscale":[[0,"#1a88ff"],[0.5,"#e6f2ff"],[1,"#ffffff"]],"hoverinfo":"none","opacity":0.75,"showscale":false,"z":[[0,0,0],[0,0.5,0.5],[0,1,1],[0,0.5,0.5],[0,1,1],[0,0.5,0.5],[0,1,1],[0,0.5,0.5]],"type":"heatmap"}],                        {"annotations":[{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b></b>","x":-0.45,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Asset</b>","x":0.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Weights_4</b>","x":1.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>0</b>","x":-0.45,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"META","x":0.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0","x":1.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>1</b>","x":-0.45,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"AMZN","x":0.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.084","x":1.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>2</b>","x":-0.45,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"NFLX","x":0.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0","x":1.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>3</b>","x":-0.45,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"GOOG","x":0.55,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.1139","x":1.55,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>4</b>","x":-0.45,"xanchor":"left","xref":"x","y":5,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"BA","x":0.55,"xanchor":"left","xref":"x","y":5,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0","x":1.55,"xanchor":"left","xref":"x","y":5,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>5</b>","x":-0.45,"xanchor":"left","xref":"x","y":6,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"V","x":0.55,"xanchor":"left","xref":"x","y":6,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0","x":1.55,"xanchor":"left","xref":"x","y":6,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>6</b>","x":-0.45,"xanchor":"left","xref":"x","y":7,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"MA","x":0.55,"xanchor":"left","xref":"x","y":7,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.8021","x":1.55,"xanchor":"left","xref":"x","y":7,"yref":"y"}],"height":290,"margin" ...

# %%
# Print portfolio's performance

annual_returns_4, annual_variance_4, annual_sd_4 = portfolioPerformance(np.array(weights_4),
                                                                        np.array(annual_mean_returns),
                                                                        annual_cov_matrix.to_numpy())

sharpeRatio_4 = SR(np.array(weights_4), np.array(annual_mean_returns), annual_cov_matrix.to_numpy(), 0)

percent_ret = str(round(annual_returns_4, 2) * 100) + '%'
percent_sd = str(round(annual_sd_4, 2) * 100 ) + '%'

print('Expected annual return        : ' + percent_ret)
print('Annual volatility / risk / sd : ' + percent_sd)
print('Sharpe ratio                  : ' + str(round(sharpeRatio_4, 2)))
# Out:
# Expected annual return        : 15.0%
# Annual volatility / risk / sd : 31.0%
# Sharpe ratio                  : 0.49

# %%
# Generate Portfolio with Optimized Weights

# Now let us generate the portfolio with optimized weights and plot out its cumulative returns over time.

my_assets_4 = my_assets.copy(deep=True)
my_assets_4['Optimized Portfolio'] = 0
for asset, weight in weights_4_dict.items():
    my_assets_4['Optimized Portfolio'] += my_assets_4[asset]*weight

my_assets_4
# Out:
#                   META        AMZN        NFLX       GOOG          BA  \
# Date
# 2017-11-06  180.169998   56.033001  200.130005  51.294998  250.311203
# 2017-11-07  180.250000   56.158501  195.889999  51.666500  252.263916
# 2017-11-08  179.559998   56.644001  196.440002  51.992500  251.733032
# 2017-11-09  179.300003   56.456501  193.899994  51.563000  250.351257
# 2017-11-10  178.460007   56.267502  192.020004  51.403500  248.588196
# ...                ...         ...         ...        ...         ...
# 2022-10-28   99.199997  103.410004  295.720001  96.580002  143.839996
# 2022-10-31   93.160004  102.440002  291.880005  94.660004  142.509995
# 2022-11-01   95.199997   96.790001  286.750000  90.500000  143.380005
# 2022-11-02   90.540001   92.120003  273.000000  87.070000  147.410004
# 2022-11-03   88.910004   89.300003  269.059998  83.489998  156.750000
#
#                      V          MA  Optimized Portfolio
# Date
# 2017-11-06  108.355034  146.081161           127.717945
# 2017-11-07  108.519608  145.964355           127.677130
# 2017-11-08  108.887527  145.964355           127.755051
# 2017-11-09  108.568031  145.302521           127.159527
# 2017-11-10  108.316322  145.545807           127.320612
# ...                ...         ...                  ...
# 2022-10-28  209.339996  329.470001           283.947425
# 2022-10-31  207.160004  328.179993           282.612507
# 2022-11-01  206.929993  333.190002           285.682348
# 2022-11-02  200.949997  319.820007           274.175646
# 2022-11-03  194.750000  309.170013           264.988853
#
# [1258 rows x 8 columns]

# %%
# Plot cumulative returns for each asset

my_df = my_assets_4[['Optimized Portfolio']]
daily_cum_returns_opt = 1 + my_df.dropna().pct_change()
daily_cum_returns_opt = daily_cum_returns_opt.cumprod()*100

title = 'Cumulative Returns of Optimized Portfolio Starting with $100'
xlabel = 'Date'
ylabel = 'Cumulative returns'

col = list(daily_cum_returns_opt.dropna())
plot_graph(col,title,xlabel,ylabel,daily_cum_returns_opt.dropna())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b2fa315a-fe9e-4706-81a3-cb026d0d8cd5" class="plotly-graph-div" style="height:500px; width:690px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2fa315a-fe9e-4706-81a3-cb026d0d8cd5")) {                    Plotly.newPlot(                        "b2fa315a-fe9e-4706-81a3-cb026d0d8cd5",                        [{"name":"Optimized Portfolio","x":["2017-11-07T00:00:00","2017-11-08T00:00:00","2017-11-09T00:00:00","2017-11-10T00:00:00","2017-11-13T00:00:00","2017-11-14T00:00:00","2017-11-15T00:00:00","2017-11-16T00:00:00","2017-11-17T00:00:00","2017-11-20T00:00:00","2017-11-21T00:00:00","2017-11-22T00:00:00","2017-11-24T00:00:00","2017-11-27T00:00:00","2017-11-28T00:00:00","2017-11-29T00:00:00","2017-11-30T00:00:00","2017-12-01T00:00:00","2017-12-04T00:00:00","2017-12-05T00:00:00","2017-12-06T00:00:00","2017-12-07T00:00:00","2017-12-08T00:00:00","2017-12-11T00:00:00","2017-12-12T00:00:00","2017-12-13T00:00:00","2017-12-14T00:00:00","2017-12-15T00:00:00","2017-12-18T00:00:00","2017-12-19T00:00:00","2017-12-20T00:00:00","2017-12-21T00:00:00","2017-12-22T00:00:00","2017-12-26T00:00:00","2017-12-27T00:00:00","2017-12-28T00:00:00","2017-12-29T00:00:00","2018-01-02T00:00:00","2018-01-03T00:00:00","2018-01-04T00:00:00","2018-01-05T00:00:00","2018-01-08T00:00:00","2018-01-09T00:00:00","2018-01-10T00:00:00","2018-01-11T00:00:00","2018-01-12T00:00:00","2018-01-16T00:00:00","2018-01-17T00:00:00","2018-01-18T00:00:00","2018-01-19T00:00:00","2018-01-22T00:00:00","2018-01-23T00:00:00","2018-01-24T00:00:00","2018-01-25T00:00:00","2018-01-26T00:00:00","2018-01-29T00:00:00","2018-01-30T00:00:00","2018-01-31T00:00:00","2018-02-01T00:00:00","2018-02-02T00:00:00","2018-02-05T00:00:00","2018-02-06T00:00:00","2018-02-07T00:00:00","2018-02-08T00:00:00","2018-02-09T00:00:00","2018-02-12T00:00:00","2018-02-13T00:00:00","2018-02-14T00:00:00","2018-02-15T00:00:00","2018-02-16T00:00:00","2018-02-20T00:00:00","2018-02-21T00:00:00","2018-02-22T00:00:00","2018-02-23T00:00:00","2018-02-26T00:00:00","2018-02-27T00:00:00","2018-02-28T00:00:00","2018-03-01T00:00:00","2018-03-02T00:00:00","2018-03-05T00:00:00","2018-03-06T00:00:00","2018-03-07T00:00:00","2018-03-08T00:00:00","2018-03-09T00:00:00","2018-03-12T00:00:00","2018-03-13T00:00:00","2018-03-14T00:00:00","2018-03-15T00:00:00","2018-03-16T00:00:00","2018-03-19T00:00:00","2018-03-20T00:00:00","2018-03-21T00:00:00","2018-03-22T00:00:00","2018-03-23T00:00:00","2018-03-26T00:00:00","2018-03-27T00:00:00","2018-03-28T00:00:00","2018-03-29T00:00:00","2018-04-02T00:00:00","2018-04-03T00:00:00","2018-04-04T00:00:00","2018-04-05T00:00:00","2018-04-06T00:00:00","2018-04-09T00:00:00","2018-04-10T00:00:00","2018-04-11T00:00:00","2018-04-12T00:00:00","2018-04-13T00:00:00","2018-04-16T00:00:00","2018-04-17T00:00:00","2018-04-18T00:00:00","2018-04-19T00:00:00","2018-04-20T00:00:00","2018-04-23T00:00:00","2018-04-24T00:00:00","2018-04-25T00:00:00","2018-04-26T00:00:00","2018-04-27T00:00:00","2018-04-30T00:00:00","2018-05-01T00:00:00","2018-05-02T00:00:00","2018-05-03T00:00:00","2018-05-04T00:00:00","2018-05-07T00:00:00","2018-05-08T00:00:00","2018-05-09T00:00:00","2018-05-10T00:00:00","2018-05-11T00:00:00","2018-05-14T00:00:00","2018-05-15T00:00:00","2018-05-16T00:00:00","2018-05-17T00:00:00","2018-05-18T00:00:00","2018-05-21T00:00:00","2018-05-22T00:00:00","2018-05-23T00:00:00","2018-05-24T00:00:00","2018-05-25T00:00:00","2018-05-29T00:00:00","2018-05-30T00:00:00","2018-05-31T00:00:00","2018-06-01T00:00:00","2018-06-04T00:00:00","2018-06-05T00:00:00","2018-06-06T00:00:00","2018-06-07T00:00:00","2018-06-08T00:00:00","2018-06-11T00:00:00","2018-06-12T00:00:00","2018-06-13T00:00:00","2018-06-14T00:00:00","2018-06-15T00:00:00","2018-06-18T00:00:00","2018-06-19T00:00:00","2018-06-20T00:00:00","2018-0 ...

# %%
# Get the discrete allocation of each share per stock

latest_prices = get_latest_prices(my_assets)
da = DiscreteAllocation(weights_4_dict, latest_prices, total_portfolio_value = 10000)

allocation, leftover = da.lp_portfolio()

print('Latest prices of assets:\n')

print(latest_prices)
print ('\nDiscrete allocation:',allocation)
print('Funds remaining: ${:.2f}'.format (leftover))
# Out:
# Latest prices of assets:
#
# META     88.910004
# AMZN     89.300003
# NFLX    269.059998
# GOOG     83.489998
# BA      156.750000
# V       194.750000
# MA      309.170013
# Name: 2022-11-03 00:00:00, dtype: float64
#
# Discrete allocation: {'AMZN': 9, 'GOOG': 13, 'MA': 26}
# Funds remaining: $72.51

# %%
############################################
# Optimize portfolio by maximizing utility #
############################################

# %%
result = maxUtility(1, np.array(annual_mean_returns), annual_cov_matrix.to_numpy(), (0,1))

maxUtilityRes, weights_5 = result['fun'], result['x']

weights_5_df = pd.DataFrame({'Asset':daily_volatility.loc[:,'Asset'], 'Weights_5':weights_5})

weights_5_dict = dict(zip(assets, weights_5.T))

plot_table(weights_5_df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="178be9cc-3714-4969-8601-818e8b9a4f65" class="plotly-graph-div" style="height:290px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("178be9cc-3714-4969-8601-818e8b9a4f65")) {                    Plotly.newPlot(                        "178be9cc-3714-4969-8601-818e8b9a4f65",                        [{"colorscale":[[0,"#1a88ff"],[0.5,"#e6f2ff"],[1,"#ffffff"]],"hoverinfo":"none","opacity":0.75,"showscale":false,"z":[[0,0,0],[0,0.5,0.5],[0,1,1],[0,0.5,0.5],[0,1,1],[0,0.5,0.5],[0,1,1],[0,0.5,0.5]],"type":"heatmap"}],                        {"annotations":[{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b></b>","x":-0.45,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Asset</b>","x":0.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>Weights_5</b>","x":1.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>0</b>","x":-0.45,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"META","x":0.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0","x":1.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>1</b>","x":-0.45,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"AMZN","x":0.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0","x":1.55,"xanchor":"left","xref":"x","y":2,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>2</b>","x":-0.45,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"NFLX","x":0.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0","x":1.55,"xanchor":"left","xref":"x","y":3,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>3</b>","x":-0.45,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"GOOG","x":0.55,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0","x":1.55,"xanchor":"left","xref":"x","y":4,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>4</b>","x":-0.45,"xanchor":"left","xref":"x","y":5,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"BA","x":0.55,"xanchor":"left","xref":"x","y":5,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0","x":1.55,"xanchor":"left","xref":"x","y":5,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>5</b>","x":-0.45,"xanchor":"left","xref":"x","y":6,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"V","x":0.55,"xanchor":"left","xref":"x","y":6,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.0","x":1.55,"xanchor":"left","xref":"x","y":6,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"<b>6</b>","x":-0.45,"xanchor":"left","xref":"x","y":7,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"MA","x":0.55,"xanchor":"left","xref":"x","y":7,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"1.0","x":1.55,"xanchor":"left","xref":"x","y":7,"yref":"y"}],"height":290,"margin":{"b":0, ...

# %%
# Print portfolio's performance

annual_returns_5, annual_variance_5, annual_sd_5 = portfolioPerformance(np.array(weights_5),
                                                                        np.array(annual_mean_returns),
                                                                        annual_cov_matrix.to_numpy())

sharpeRatio_5 = SR(np.array(weights_5), np.array(annual_mean_returns), annual_cov_matrix.to_numpy(), 0)

percent_ret = str(round(annual_returns_5, 2) * 100) + '%'
percent_sd = str(round(annual_sd_5, 2) * 100 ) + '%'

print('Expected annual return        : ' + percent_ret)
print('Annual volatility / risk / sd : ' + percent_sd)
print('Sharpe ratio                  : ' + str(round(sharpeRatio_5, 2)))
# Out:
# Expected annual return        : 16.0%
# Annual volatility / risk / sd : 33.0%
# Sharpe ratio                  : 0.49

# %%
# Generate Portfolio with Optimized Weights

# Now let us generate the portfolio with optimized weights and plot out its cumulative returns over time.

my_assets_5 = my_assets.copy(deep=True)
my_assets_5['Optimized Portfolio'] = 0
for asset, weight in weights_4_dict.items():
    my_assets_5['Optimized Portfolio'] += my_assets_5[asset]*weight

my_assets_5
# Out:
#                   META        AMZN        NFLX       GOOG          BA  \
# Date
# 2017-11-06  180.169998   56.033001  200.130005  51.294998  250.311203
# 2017-11-07  180.250000   56.158501  195.889999  51.666500  252.263916
# 2017-11-08  179.559998   56.644001  196.440002  51.992500  251.733032
# 2017-11-09  179.300003   56.456501  193.899994  51.563000  250.351257
# 2017-11-10  178.460007   56.267502  192.020004  51.403500  248.588196
# ...                ...         ...         ...        ...         ...
# 2022-10-28   99.199997  103.410004  295.720001  96.580002  143.839996
# 2022-10-31   93.160004  102.440002  291.880005  94.660004  142.509995
# 2022-11-01   95.199997   96.790001  286.750000  90.500000  143.380005
# 2022-11-02   90.540001   92.120003  273.000000  87.070000  147.410004
# 2022-11-03   88.910004   89.300003  269.059998  83.489998  156.750000
#
#                      V          MA  Optimized Portfolio
# Date
# 2017-11-06  108.355034  146.081161           127.717945
# 2017-11-07  108.519608  145.964355           127.677130
# 2017-11-08  108.887527  145.964355           127.755051
# 2017-11-09  108.568031  145.302521           127.159527
# 2017-11-10  108.316322  145.545807           127.320612
# ...                ...         ...                  ...
# 2022-10-28  209.339996  329.470001           283.947425
# 2022-10-31  207.160004  328.179993           282.612507
# 2022-11-01  206.929993  333.190002           285.682348
# 2022-11-02  200.949997  319.820007           274.175646
# 2022-11-03  194.750000  309.170013           264.988853
#
# [1258 rows x 8 columns]

# %%
# Plot cumulative returns for each asset

my_df = my_assets_5[['Optimized Portfolio']]
daily_cum_returns_opt = 1 + my_df.dropna().pct_change()
daily_cum_returns_opt = daily_cum_returns_opt.cumprod()*100

title = 'Cumulative Returns of Optimized Portfolio Starting with $100'
xlabel = 'Date'
ylabel = 'Cumulative returns'

col = list(daily_cum_returns_opt.dropna())
plot_graph(col,title,xlabel,ylabel,daily_cum_returns_opt.dropna())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0c462c79-4cbd-4ea1-86c8-fdfaf7075646" class="plotly-graph-div" style="height:500px; width:690px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c462c79-4cbd-4ea1-86c8-fdfaf7075646")) {                    Plotly.newPlot(                        "0c462c79-4cbd-4ea1-86c8-fdfaf7075646",                        [{"name":"Optimized Portfolio","x":["2017-11-07T00:00:00","2017-11-08T00:00:00","2017-11-09T00:00:00","2017-11-10T00:00:00","2017-11-13T00:00:00","2017-11-14T00:00:00","2017-11-15T00:00:00","2017-11-16T00:00:00","2017-11-17T00:00:00","2017-11-20T00:00:00","2017-11-21T00:00:00","2017-11-22T00:00:00","2017-11-24T00:00:00","2017-11-27T00:00:00","2017-11-28T00:00:00","2017-11-29T00:00:00","2017-11-30T00:00:00","2017-12-01T00:00:00","2017-12-04T00:00:00","2017-12-05T00:00:00","2017-12-06T00:00:00","2017-12-07T00:00:00","2017-12-08T00:00:00","2017-12-11T00:00:00","2017-12-12T00:00:00","2017-12-13T00:00:00","2017-12-14T00:00:00","2017-12-15T00:00:00","2017-12-18T00:00:00","2017-12-19T00:00:00","2017-12-20T00:00:00","2017-12-21T00:00:00","2017-12-22T00:00:00","2017-12-26T00:00:00","2017-12-27T00:00:00","2017-12-28T00:00:00","2017-12-29T00:00:00","2018-01-02T00:00:00","2018-01-03T00:00:00","2018-01-04T00:00:00","2018-01-05T00:00:00","2018-01-08T00:00:00","2018-01-09T00:00:00","2018-01-10T00:00:00","2018-01-11T00:00:00","2018-01-12T00:00:00","2018-01-16T00:00:00","2018-01-17T00:00:00","2018-01-18T00:00:00","2018-01-19T00:00:00","2018-01-22T00:00:00","2018-01-23T00:00:00","2018-01-24T00:00:00","2018-01-25T00:00:00","2018-01-26T00:00:00","2018-01-29T00:00:00","2018-01-30T00:00:00","2018-01-31T00:00:00","2018-02-01T00:00:00","2018-02-02T00:00:00","2018-02-05T00:00:00","2018-02-06T00:00:00","2018-02-07T00:00:00","2018-02-08T00:00:00","2018-02-09T00:00:00","2018-02-12T00:00:00","2018-02-13T00:00:00","2018-02-14T00:00:00","2018-02-15T00:00:00","2018-02-16T00:00:00","2018-02-20T00:00:00","2018-02-21T00:00:00","2018-02-22T00:00:00","2018-02-23T00:00:00","2018-02-26T00:00:00","2018-02-27T00:00:00","2018-02-28T00:00:00","2018-03-01T00:00:00","2018-03-02T00:00:00","2018-03-05T00:00:00","2018-03-06T00:00:00","2018-03-07T00:00:00","2018-03-08T00:00:00","2018-03-09T00:00:00","2018-03-12T00:00:00","2018-03-13T00:00:00","2018-03-14T00:00:00","2018-03-15T00:00:00","2018-03-16T00:00:00","2018-03-19T00:00:00","2018-03-20T00:00:00","2018-03-21T00:00:00","2018-03-22T00:00:00","2018-03-23T00:00:00","2018-03-26T00:00:00","2018-03-27T00:00:00","2018-03-28T00:00:00","2018-03-29T00:00:00","2018-04-02T00:00:00","2018-04-03T00:00:00","2018-04-04T00:00:00","2018-04-05T00:00:00","2018-04-06T00:00:00","2018-04-09T00:00:00","2018-04-10T00:00:00","2018-04-11T00:00:00","2018-04-12T00:00:00","2018-04-13T00:00:00","2018-04-16T00:00:00","2018-04-17T00:00:00","2018-04-18T00:00:00","2018-04-19T00:00:00","2018-04-20T00:00:00","2018-04-23T00:00:00","2018-04-24T00:00:00","2018-04-25T00:00:00","2018-04-26T00:00:00","2018-04-27T00:00:00","2018-04-30T00:00:00","2018-05-01T00:00:00","2018-05-02T00:00:00","2018-05-03T00:00:00","2018-05-04T00:00:00","2018-05-07T00:00:00","2018-05-08T00:00:00","2018-05-09T00:00:00","2018-05-10T00:00:00","2018-05-11T00:00:00","2018-05-14T00:00:00","2018-05-15T00:00:00","2018-05-16T00:00:00","2018-05-17T00:00:00","2018-05-18T00:00:00","2018-05-21T00:00:00","2018-05-22T00:00:00","2018-05-23T00:00:00","2018-05-24T00:00:00","2018-05-25T00:00:00","2018-05-29T00:00:00","2018-05-30T00:00:00","2018-05-31T00:00:00","2018-06-01T00:00:00","2018-06-04T00:00:00","2018-06-05T00:00:00","2018-06-06T00:00:00","2018-06-07T00:00:00","2018-06-08T00:00:00","2018-06-11T00:00:00","2018-06-12T00:00:00","2018-06-13T00:00:00","2018-06-14T00:00:00","2018-06-15T00:00:00","2018-06-18T00:00:00","2018-06-19T00:00:00","2018-06-20T00:00:00","2018-0 ...

# %%
# Get the discrete allocation of each share per stock

latest_prices = get_latest_prices(my_assets)
da = DiscreteAllocation(weights_5_dict, latest_prices, total_portfolio_value = 10000)

allocation, leftover = da.lp_portfolio()

print('Latest prices of assets:\n')

print(latest_prices)
print ('\nDiscrete allocation:',allocation)
print('Funds remaining: ${:.2f}'.format (leftover))
# Out:
# Latest prices of assets:
#
# META     88.910004
# AMZN     89.300003
# NFLX    269.059998
# GOOG     83.489998
# BA      156.750000
# V       194.750000
# MA      309.170013
# Name: 2022-11-03 00:00:00, dtype: float64
#
# Discrete allocation: {'MA': 32}
# Funds remaining: $106.56

# %%
import scipy.io
cm = annual_cov_matrix.to_numpy()
scipy.io.savemat('covMat.mat',dict(x=cm))

# %%
scipy.io.savemat('meanReturns.mat',dict(x=np.array(annual_mean_returns)))
